# %%
# Run sourcing
import subprocess
subprocess.run(['python', '../cli/run_sourcing.py', '--costs-au', '../../data/cost_inputs_au.csv'])

# %%
# Run CEA
subprocess.run(['python', '../cli/run_cea.py', '--jur', 'AU', '--perspective', 'health_system'])

# %%
# Run PSA
subprocess.run(['python', '../cli/run_psa.py'])

# %%
# Run DSA
subprocess.run(['python', '../cli/run_dsa.py'])

# Run DCEA
subprocess.run(['python', '../cli/run_dcea.py'])

# Generate pricing plot
from plots.pricing import plot_pricing
plot_pricing(None, output_path='../out/pricing_v3.png')

# Generate equity visuals
from plots.equity import plot_equity_impact, plot_distributional_ceac, plot_rac
plot_equity_impact(None, output_path='../out/equity_impact_v3.png')
plot_distributional_ceac(None, output_path='../out/distributional_ceac_v3.png')
plot_rac(None, output_path='../out/rac_v3.png')

# %% [markdown]
# # nextgen_v3 Analysis Notebook
#
# This notebook is for analysis in the nextgen_v3 framework.
